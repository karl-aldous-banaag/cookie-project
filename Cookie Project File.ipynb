# %% [markdown]
# # Downloading Data

# %% [markdown]
# ## Getting Text of Dataset

# %%
data_file = open("DS163 PROJECT DATASET.txt", mode="r", encoding = "ISO-8859-1")
data_text = data_file.read()
data_file.close()

# %%
data_text
# Out:
# ' \n\n\n1  \n all purpose flour  \n 3.0 cups all purpose flour  \n AR_1  \n 0.920724583  \n 3  \n cup\n2  \n all purpose flour  \n 2.8000000000000003 cups all purpose flour  \n AR_10  \n 0.905162048  \n 2.8  \n cup\n3  \n all purpose flour  \n 1.1076923076923078 cups all purpose flour  \n AR_101  \n 0.6  \n 1.107692308  \n cup\n4  \n all purpose flour  \n 3.333333333333333 cups sifted all purpose flour  \n AR_102  \n 0.9375  \n 3.333333333  \n cup\n5  \n all purpose flour  \n 2.0 cups all purpose flour  \n AR_103  \n 0.88125  \n 2  \n cup\n6  \n all purpose flour  \n 9.0 cups unbleached all purpose flour  \n AR_107  \n 0.927272701  \n 9  \n cup\n7  \n all purpose flour  \n 0.8571428571428571 cups all purpose flour  \n AR_108  \n 0.867741966  \n 0.857142857  \n cup\n8  \n all purpose flour  \n 2.6666666666666665 cups all purpose flour  \n AR_109  \n 0.871794891  \n 2.666666667  \n cup\n9  \n all purpose flour  \n 3.333333333333333 cups all purpose flour  \n AR_11  \n 0.902891922  \n 3.333333333  \n cup\n10  \n all purpose flour  \n 4.0 cups all purpose flour  \n AR_110  \n 0.868292713  \n 4  \n cup\n11  \n all purpose flour  \n 5.0 cups all purpose flour or more as needed  \n AR_111  \n 1  \n 5  \n cup\n12  \n all purpose flour  \n 1.125 cups all purpose flour  \n AR_116  \n 0.847999954  \n 1.125  \n cup\n13  \n all purpose flour  \n 2.0 cups all purpose flour  \n AR_118  \n 0.830769253  \n 2  \n cup\n14  \n all purpose flour  \n 3.5 cups all purpose flour  \n AR_119  \n 0.845714283  \n 3.5  \n cup\n15  \n all purpose flour  \n 2.5 cups flour  \n AR_12  \n 0.873469353  \n 2.5  \n cup\n16  \n all purpose flour  \n 4.5 cups all purpose flour  \n AR_128  \n 0.714285707  \n 4.5  \n cup\n17  \n all purpose flour  \n 4.5 cups all purpose flour  \n AR_13  \n 0.909016418  \n 4.5  \n cup\n18 \\n all purpose flour  \n 1.3333333333333333 cups all purpose flour  \n AR_14  \n 0.90666666  \n 1.333333333  \n cup\n19  \n all purpose flour  \n 3.111111111111111 cups all purpose flour  \n AR_140  \n 0.584615374  \n 3.111111111  \n cup\n20  \n all purpose flour  \n 3.333333333333333 cups sifted all purpose flour  \n AR_141  \n 0.784615374  \n 3.333333333  \n cup\n21  \n all purpose flour  \n 3.0 cups all purpose flour  \n AR_142  \n 0.671428585  \n 3  \n cup\n22  \n all purpose flour  \n 2.0 cup sifted all purpose flour  \n AR_144  \n 0.442857122  \n 2  \n cup\n23  \n all purpose flour  \n 2.25 cups all purpose flour  \n AR_15  \n 0.924302769  \n 2.25  \n cup\n24  \n all purpose flour  \n 3.0 cups all purpose flour  \n AR_155  \n 0.931135178  \n 3  \n cup\n25  \n all purpose flour  \n 8.0 cups all purpose flour  \n AR_156  \n 0.924294472  \n 8  \n cup\n26  \n all purpose flour  \n 2.2857142857142856 cups all purpose flour  \n AR_16  \n 0.85882349  \n 2.285714286  \n cup\n27  \n all purpose flour  \n 2.25 cups all purpose flour  \n AR_164  \n 0.917012405  \n 2.25  \n cup\n28  \n all purpose flour  \n 3.5555555555555554 cups all purpose flour  \n AR_169  \n 0.873728848  \n 3.555555556  \n cup\n29  \n all purpose flour  \n 2.6666666666666665 cups all purpose flour  \n AR_19  \n 0.880000019  \n 2.666666667  \n cup\n30  \n all purpose flour  \n 6.0 cups all purpose flour  \n AR_195  \n 0.585714293  \n 6  \n cup\n31  \n all purpose flour  \n 3.0 cups all purpose flour  \n AR_196  \n 0.785929632  \n 3  \n cup\n32  \n all purpose flour  \n 4.0 cup all purpose flour  \n AR_197  \n 0.706521749  \n 4  \n cup\n33  \n all purpose flour  \n 1.3333333333333333 cup all purpose flour  \n AR_2  \n 0.937981987  \n 1.333333333  \n cup\n34  \n all purpose flour  \n 4.666666666666666 cups all purpose flour  \n AR_21  \n 0.881944466  \n 4.666666667  \n cup\n35  \n all purpose flour  \n 2.6666666666666665 cups all purpose flour  \n AR_218  \n 0.877419376  \n 2.666666667  \n cup\n36  \n all purpose flour  \n 7.0 cups all purpose flour  \n AR_256  \n 0.870253181  \n 7  \n cup\n37  \n all purpose flour  \n 2.5 cups all purpose flour  \n AR_26  \n 0.9  \n 2.5  \n cup\n38  \ ...

# %% [markdown]
# ## Cleaning Lines of Data

# %% [markdown]
# Some of the lines contain `\n` and not an actual new line. So, the researchers replaced `\\n` with `\n`

# %%
import re

data_text = re.sub(r"\\n", '\n', data_text)
data_text
# Out:
# ' \n\n\n1  \n all purpose flour  \n 3.0 cups all purpose flour  \n AR_1  \n 0.920724583  \n 3  \n cup\n2  \n all purpose flour  \n 2.8000000000000003 cups all purpose flour  \n AR_10  \n 0.905162048  \n 2.8  \n cup\n3  \n all purpose flour  \n 1.1076923076923078 cups all purpose flour  \n AR_101  \n 0.6  \n 1.107692308  \n cup\n4  \n all purpose flour  \n 3.333333333333333 cups sifted all purpose flour  \n AR_102  \n 0.9375  \n 3.333333333  \n cup\n5  \n all purpose flour  \n 2.0 cups all purpose flour  \n AR_103  \n 0.88125  \n 2  \n cup\n6  \n all purpose flour  \n 9.0 cups unbleached all purpose flour  \n AR_107  \n 0.927272701  \n 9  \n cup\n7  \n all purpose flour  \n 0.8571428571428571 cups all purpose flour  \n AR_108  \n 0.867741966  \n 0.857142857  \n cup\n8  \n all purpose flour  \n 2.6666666666666665 cups all purpose flour  \n AR_109  \n 0.871794891  \n 2.666666667  \n cup\n9  \n all purpose flour  \n 3.333333333333333 cups all purpose flour  \n AR_11  \n 0.902891922  \n 3.333333333  \n cup\n10  \n all purpose flour  \n 4.0 cups all purpose flour  \n AR_110  \n 0.868292713  \n 4  \n cup\n11  \n all purpose flour  \n 5.0 cups all purpose flour or more as needed  \n AR_111  \n 1  \n 5  \n cup\n12  \n all purpose flour  \n 1.125 cups all purpose flour  \n AR_116  \n 0.847999954  \n 1.125  \n cup\n13  \n all purpose flour  \n 2.0 cups all purpose flour  \n AR_118  \n 0.830769253  \n 2  \n cup\n14  \n all purpose flour  \n 3.5 cups all purpose flour  \n AR_119  \n 0.845714283  \n 3.5  \n cup\n15  \n all purpose flour  \n 2.5 cups flour  \n AR_12  \n 0.873469353  \n 2.5  \n cup\n16  \n all purpose flour  \n 4.5 cups all purpose flour  \n AR_128  \n 0.714285707  \n 4.5  \n cup\n17  \n all purpose flour  \n 4.5 cups all purpose flour  \n AR_13  \n 0.909016418  \n 4.5  \n cup\n18 \n all purpose flour  \n 1.3333333333333333 cups all purpose flour  \n AR_14  \n 0.90666666  \n 1.333333333  \n cup\n19  \n all purpose flour  \n 3.111111111111111 cups all purpose flour  \n AR_140  \n 0.584615374  \n 3.111111111  \n cup\n20  \n all purpose flour  \n 3.333333333333333 cups sifted all purpose flour  \n AR_141  \n 0.784615374  \n 3.333333333  \n cup\n21  \n all purpose flour  \n 3.0 cups all purpose flour  \n AR_142  \n 0.671428585  \n 3  \n cup\n22  \n all purpose flour  \n 2.0 cup sifted all purpose flour  \n AR_144  \n 0.442857122  \n 2  \n cup\n23  \n all purpose flour  \n 2.25 cups all purpose flour  \n AR_15  \n 0.924302769  \n 2.25  \n cup\n24  \n all purpose flour  \n 3.0 cups all purpose flour  \n AR_155  \n 0.931135178  \n 3  \n cup\n25  \n all purpose flour  \n 8.0 cups all purpose flour  \n AR_156  \n 0.924294472  \n 8  \n cup\n26  \n all purpose flour  \n 2.2857142857142856 cups all purpose flour  \n AR_16  \n 0.85882349  \n 2.285714286  \n cup\n27  \n all purpose flour  \n 2.25 cups all purpose flour  \n AR_164  \n 0.917012405  \n 2.25  \n cup\n28  \n all purpose flour  \n 3.5555555555555554 cups all purpose flour  \n AR_169  \n 0.873728848  \n 3.555555556  \n cup\n29  \n all purpose flour  \n 2.6666666666666665 cups all purpose flour  \n AR_19  \n 0.880000019  \n 2.666666667  \n cup\n30  \n all purpose flour  \n 6.0 cups all purpose flour  \n AR_195  \n 0.585714293  \n 6  \n cup\n31  \n all purpose flour  \n 3.0 cups all purpose flour  \n AR_196  \n 0.785929632  \n 3  \n cup\n32  \n all purpose flour  \n 4.0 cup all purpose flour  \n AR_197  \n 0.706521749  \n 4  \n cup\n33  \n all purpose flour  \n 1.3333333333333333 cup all purpose flour  \n AR_2  \n 0.937981987  \n 1.333333333  \n cup\n34  \n all purpose flour  \n 4.666666666666666 cups all purpose flour  \n AR_21  \n 0.881944466  \n 4.666666667  \n cup\n35  \n all purpose flour  \n 2.6666666666666665 cups all purpose flour  \n AR_218  \n 0.877419376  \n 2.666666667  \n cup\n36  \n all purpose flour  \n 7.0 cups all purpose flour  \n AR_256  \n 0.870253181  \n 7  \n cup\n37  \n all purpose flour  \n 2.5 cups all purpose flour  \n AR_26  \n 0.9  \n 2.5  \n cup\n38  \n ...

# %% [markdown]
# Then, the researchers split the data by `\n`.

# %%
data_lines = data_text.split('\n')

# %% [markdown]
# Once they fixed the separation of lines, they cleaned the lines themselves.<br>

# %%
data_lines = [ re.sub(r"\s+?\n", '', line) for line in data_lines ]
data_lines = [ line for line in data_lines if not line.isspace() ]
data_lines = [ line for line in data_lines if len(line) > 0 ]
data_lines = [ re.sub(r"\s+", ' ', line) for line in data_lines ]
data_lines = [ line[:-1] if line[-1] == ' ' else line for line in data_lines ] # removes last character if it is space
data_lines
# Out:
# ['1',
#  ' all purpose flour',
#  ' 3.0 cups all purpose flour',
#  ' AR_1',
#  ' 0.920724583',
#  ' 3',
#  ' cup',
#  '2',
#  ' all purpose flour',
#  ' 2.8000000000000003 cups all purpose flour',
#  ' AR_10',
#  ' 0.905162048',
#  ' 2.8',
#  ' cup',
#  '3',
#  ' all purpose flour',
#  ' 1.1076923076923078 cups all purpose flour',
#  ' AR_101',
#  ' 0.6',
#  ' 1.107692308',
#  ' cup',
#  '4',
#  ' all purpose flour',
#  ' 3.333333333333333 cups sifted all purpose flour',
#  ' AR_102',
#  ' 0.9375',
#  ' 3.333333333',
#  ' cup',
#  '5',
#  ' all purpose flour',
#  ' 2.0 cups all purpose flour',
#  ' AR_103',
#  ' 0.88125',
#  ' 2',
#  ' cup',
#  '6',
#  ' all purpose flour',
#  ' 9.0 cups unbleached all purpose flour',
#  ' AR_107',
#  ' 0.927272701',
#  ' 9',
#  ' cup',
#  '7',
#  ' all purpose flour',
#  ' 0.8571428571428571 cups all purpose flour',
#  ' AR_108',
#  ' 0.867741966',
#  ' 0.857142857',
#  ' cup',
#  '8',
#  ' all purpose flour',
#  ' 2.6666666666666665 cups all purpose flour',
#  ' AR_109',
#  ' 0.871794891',
#  ' 2.666666667',
#  ' cup',
#  '9',
#  ' all purpose flour',
#  ' 3.333333333333333 cups all purpose flour',
#  ' AR_11',
#  ' 0.902891922',
#  ' 3.333333333',
#  ' cup',
#  '10',
#  ' all purpose flour',
#  ' 4.0 cups all purpose flour',
#  ' AR_110',
#  ' 0.868292713',
#  ' 4',
#  ' cup',
#  '11',
#  ' all purpose flour',
#  ' 5.0 cups all purpose flour or more as needed',
#  ' AR_111',
#  ' 1',
#  ' 5',
#  ' cup',
#  '12',
#  ' all purpose flour',
#  ' 1.125 cups all purpose flour',
#  ' AR_116',
#  ' 0.847999954',
#  ' 1.125',
#  ' cup',
#  '13',
#  ' all purpose flour',
#  ' 2.0 cups all purpose flour',
#  ' AR_118',
#  ' 0.830769253',
#  ' 2',
#  ' cup',
#  '14',
#  ' all purpose flour',
#  ' 3.5 cups all purpose flour',
#  ' AR_119',
#  ' 0.845714283',
#  ' 3.5',
#  ' cup',
#  '15',
#  ' all purpose flour',
#  ' 2.5 cups flour',
#  ' AR_12',
#  ' 0.873469353',
#  ' 2.5',
#  ' cup',
#  '16',
#  ' all purpose flour',
#  ' 4.5 cups all purpose flour',
#  ' AR_128',
#  ' 0.714285707',
#  ' 4.5',
#  ' cup',
#  '17',
#  ' all purpose flour',
#  ' 4.5 cups all purpose flour',
#  ' AR_13',
#  ' 0.909016418',
#  ' 4.5',
#  ' cup',
#  '18',
#  ' all purpose flour',
#  ' 1.3333333333333333 cups all purpose flour',
#  ' AR_14',
#  ' 0.90666666',
#  ' 1.333333333',
#  ' cup',
#  '19',
#  ' all purpose flour',
#  ' 3.111111111111111 cups all purpose flour',
#  ' AR_140',
#  ' 0.584615374',
#  ' 3.111111111',
#  ' cup',
#  '20',
#  ' all purpose flour',
#  ' 3.333333333333333 cups sifted all purpose flour',
#  ' AR_141',
#  ' 0.784615374',
#  ' 3.333333333',
#  ' cup',
#  '21',
#  ' all purpose flour',
#  ' 3.0 cups all purpose flour',
#  ' AR_142',
#  ' 0.671428585',
#  ' 3',
#  ' cup',
#  '22',
#  ' all purpose flour',
#  ' 2.0 cup sifted all purpose flour',
#  ' AR_144',
#  ' 0.442857122',
#  ' 2',
#  ' cup',
#  '23',
#  ' all purpose flour',
#  ' 2.25 cups all purpose flour',
#  ' AR_15',
#  ' 0.924302769',
#  ' 2.25',
#  ' cup',
#  '24',
#  ' all purpose flour',
#  ' 3.0 cups all purpose flour',
#  ' AR_155',
#  ' 0.931135178',
#  ' 3',
#  ' cup',
#  '25',
#  ' all purpose flour',
#  ' 8.0 cups all purpose flour',
#  ' AR_156',
#  ' 0.924294472',
#  ' 8',
#  ' cup',
#  '26',
#  ' all purpose flour',
#  ' 2.2857142857142856 cups all purpose flour',
#  ' AR_16',
#  ' 0.85882349',
#  ' 2.285714286',
#  ' cup',
#  '27',
#  ' all purpose flour',
#  ' 2.25 cups all purpose flour',
#  ' AR_164',
#  ' 0.917012405',
#  ' 2.25',
#  ' cup',
#  '28',
#  ' all purpose flour',
#  ' 3.5555555555555554 cups all purpose flour',
#  ' AR_169',
#  ' 0.873728848',
#  ' 3.555555556',
#  ' cup',
#  '29',
#  ' all purpose flour',
#  ' 2.6666666666666665 cups all purpose flour',
#  ' AR_19',
#  ' 0.880000019',
#  ' 2.666666667',
#  ' cup',
#  '30',
#  ' all purpose flour',
#  ' 6.0 cups all purpose flour',
#  ' AR_195',
#  ' 0.585714293',
#  ' 6',
#  ' cup',
#  '31',
#  ' all purpose flour',
#  ' 3.0 cups all purpose flour',
#  ' AR_196',
#  ' 0.785929632',
#  ' 3',
#  ' cup',
#  '32',
#  ' all purpose flour',
#  ' 4.0 cup all purpose flour',
#  ' AR_197',
#  ' 0.706521749',
#  ' 4',
#  ' cup',
#  '33',
#  ' all purpose flour',
#  ' 1.3333333333333333 cup all purpose flour',
#  ' AR_2',
#  ' 0.937981987',
#  ' 1.333333333',
#  ' cup',
#  '34',
#  ' all purpose flour',
#  ' 4.666666666666666 cups all purpose flour',
#  ' AR_21',
#  ' 0.881944466',
#  ' 4.666666667',
#  ' cup',
#  '35',
#  ' all purpose flour',
#  ' 2.6666666666666665 cups all purpose flour',
#  ' AR_218',
#  ' 0.877419376',
#  ' 2.666666667',
#  ' cup',
#  '36',
#  ' all purpose flour',
#  ' 7.0 cups all purpose flour',
#  ' AR_256',
#  ' 0.870253181',
#  ' 7',
#  ' cup',
#  '37',
#  ' all purpose flour',
#  ' 2.5 cups all purpose flour',
#  ' AR_26',
#  ' 0.9',
#  ' 2.5',
#  ' cup',
#  '38',
#  ' all purpose flour',
#  ' 4.333333333333333 cups all purpose flour',
#  ' AR_27',
#  ' 0.876923084',
#  ' 4.333333333',
#  ' cup',
#  '39',
#  ' all purpose flour',
#  ' 4.5 cups all purpose flour',
#  ' AR_28',
#  ' 0.873333359',
#  ' 4.5',
#  ' cup',
#  '40',
#  ' all purpose flour',
#  ' 1.5 cups all purpose flour',
#  ' AR_280',
#  ' NA',
#  ' 1.5',
#  ' cup',
#  '41',
#  ' all purpose flour',
#  ' 2.25 cups all purpose flour',
#  ' AR_3',
#  ' 0.917986774',
#  ' 2.25',
#  ' cup',
#  '42',
#  ' all purpose flour',
#  ' 1.125 cups all purpose flour',
#  ' AR_30',
#  ' 0.859829044',
#  ' 1.125',
#  ' cup',
#  '43',
#  ' all purpose flour',
#  ' 3.6 cups all purpose flour',
#  ' AR_32',
#  ' 0.830769253',
#  ' 3.6',
#  ' cup',
#  '44',
#  ' all purpose flour',
#  ' 3.333333333333333 cups all purpose flour',
#  ' AR_33',
#  ' 0.826666641',
#  ' 3.333333333',
#  ' cup',
#  '45',
#  ' all purpose flour',
#  ' 4.0 cup all purpose flour',
#  ' AR_35',
#  ' 0.843636322',
#  ' 4',
#  ' cup',
#  '46',
#  ' all purpose flour',
#  ' 5.333333333333333 cups all purpose flour',
#  ' AR_37',
#  ' 0.8',
#  ' 5.333333333',
#  ' cup',
#  '47',
#  ' all purpose flour',
#  ' 2.0 cups all purpose flour',
#  ' AR_39',
#  ' 0.6',
#  ' 2',
#  ' cup',
#  '48',
#  ' all purpose flour',
#  ' 2.5 cups all purpose flour',
#  ' AR_4',
#  ' 0.922985077',
#  ' 2.5',
#  ' cup',
#  '49',
#  ' all purpose flour',
#  ' 5.0 cups all purpose flour',
#  ' AR_43',
#  ' 0.828866005',
#  ' 5',
#  ' cup',
#  '50',
#  ' all purpose flour',
#  ' 2.75 cups all purpose flour',
#  ' AR_45',
#  ' 0.821052647',
#  ' 2.75',
#  ' cup',
#  '51',
#  ' all purpose flour',
#  ' 8.0 cups all purpose flour',
#  ' AR_47',
#  ' 0.7125',
#  ' 8',
#  ' cup',
#  '52',
#  ' all purpose flour',
#  ' 5.0 cups all purpose flour',
#  ' AR_48',
#  ' 0.677777767',
#  ' 5',
#  ' cup',
#  '53',
#  ' all purpose flour',
#  ' 2.333333333333333 cups all purpose flour',
#  ' AR_49',
#  ' 0.592592573',
#  ' 2.333333333',
#  ' cup',
#  '54',
#  ' all purpose flour',
#  ' 2.25 cups all purpose flour',
#  ' AR_5',
#  ' 0.937341785',
#  ' 2.25',
#  ' cup',
#  '55',
#  ' all purpose flour',
#  ' 6.0 cups all purpose flour',
#  ' AR_50',
#  ' 0.66500001',
#  ' 6',
#  ' cup',
#  '56',
#  ' all purpose flour',
#  ' 4.0 cups all purpose flour',
#  ' AR_53',
#  ' 0.692473125',
#  ' 4',
#  ' cup',
#  '57',
#  ' all purpose flour',
#  ' 2.0 cup all purpose flour',
#  ' AR_54',
#  ' 0.723741007',
#  ' 2',
#  ' cup',
#  '58',
#  ' all purpose flour',
#  ' 3.5 cups all purpose flour',
#  ' AR_55',
#  ' 0.385714293',
#  ' 3.5',
#  ' cup',
#  '59',
#  ' all purpose flour',
#  ' 2.0 cups all purpose flour',
#  ' AR_57',
#  ' 0.595505619',
#  ' 2',
#  ' cup',
#  '60',
#  ' all purpose flour',
#  ' 4.5 cups all purpose flour',
#  ' AR_66',
#  ' 0.902002907',
#  ' 4.5',
#  ' cup',
#  '61',
#  ' all purpose flour',
#  ' 3.375 cups all purpose flour',
#  ' AR_67',
#  ' 0.939130402',
#  ' 3.375',
#  ' cup',
#  '62',
#  ' all purpose flour',
#  ' 3.375 cups all purpose flour',
#  ' AR_69',
#  ' 0.920792103',
#  ' 3.375',
#  ' cup',
#  '63',
#  ' all purpose flour',
#  ' 2.2222222222222223 cups all purpose flour',
#  ' AR_7',
#  ' 0.896335125',
#  ' 2.222222222',
#  ' cup',
#  '64',
#  ' all purpose flour',
#  ' 1.6 cups all purpose flour',
#  ' AR_70',
#  ' 0.91003809',
#  ' 1.6',
#  ' cup',
#  '65',
#  ' all purpose flour',
#  ' 2.5 cups all purpose flour',
#  ' AR_78',
#  ' 0.915186214',
#  ' 2.5',
#  ' cup',
#  '66',
#  ' all purpose flour',
#  ' 5.0 cups all purpose flour',
#  ' AR_79',
#  ' 0.633333349',
#  ' 5',
#  ' cup',
#  '67',
#  ' all purpose flour',
#  ' 4.5 cups all purpose flour',
#  ' AR_8',
#  ' 0.942446041',
#  ' 4.5',
#  ' cup',
#  '68',
#  ' all purpose flour',
#  ' 7.0 cups all purpose flour',
#  ' AR_84',
#  ' 0.905737686',
#  ' 7',
#  ' cup',
#  '69',
#  ' all purpose flour',
#  ' 2.5 cups all purpose flour',
#  ' AR_88',
#  ' 0.955555534',
#  ' 2.5',
#  ' cup',
#  '70',
#  ' all purpose flour',
#  ' 1.8 cups all purpose flour',
#  ' AR_89',
#  ' 0.909890079',
#  ' 1.8',
#  ' cup',
#  '71',
#  ' all purpose flour',
#  ' 5.0 cups all purpose flour',
#  ' AR_90',
#  ' 0.902608681',
#  ' 5',
#  ' cup',
#  '72',
#  ' all purpose flour',
#  ' 4.0 cups all purpose flour',
#  ' AR_91',
#  ' 0.928301907',
#  ' 4',
#  ' cup',
#  '73',
#  ' all purpose flour',
#  ' 4.0 cups all purpose flour',
#  ' AR_95',
#  ' 0.844067764',
#  ' 4',
#  ' cup',
#  '74',
#  ' all purpose flour',
#  ' 2.333333333333333 cups all purpose flour',
#  ' AR_96',
#  ' 0.818181801',
#  ' 2.333333333',
#  ' cup',
#  '75',
#  ' all purpose flour',
#  ' 1.8 cups all purpose flour',
#  ' AR_97',
#  ' 0.933333302',
#  ' 1.8',
#  ' cup',
#  '76',
#  ' all purpose flour',
#  ' 5.8133333333333335 cups all purpose flour',
#  ' AR_98',
#  ' 0.90666666',
#  ' 5.813333333',
#  ' cup',
#  '77',
#  ' all purpose flour',
#  ' 1.0 cup plus 2 tablespoons all purpose flour',
#  ' E_133',
#  ' 0.75',
#  ' 1',
#  ' cup',
#  '78',
#  ' all purpose flour',
#  ' 192.0 tablespoons plain all purpose flour',
#  ' E_169',
#  ' 0.5',
#  ' 12',
#  ' cup',
#  '79',
#  ' all purpose flour',
#  ' 2.4 cup plus 2 tablespoons all purpose flour',
#  ' E_21',
#  ' 0.75',
#  ' 2.4',
#  ' cup',
#  '80',
#  ' all purpose flour',
#  ' 3.0 cups all purpose flour',
#  ' E_215',
#  ' 0.875',
#  ' 3',
#  ' cup',
#  '81',
#  ' all purpose flour',
#  ' 2.0 cups all purpose flour',
#  ' E_220',
#  ' 0.75',
#  ' 2',
#  ' cup',
#  '82',
#  ' all purpose flour',
#  ' 5.14285714286 cups all purpose flour',
#  ' E_230',
#  ' 0.875',
#  ' 5.142857143',
#  ' cup',
#  '83',
#  ' all purpose flour',
#  ' 3.5 cups all purpose flour',
#  ' E_258',
#  ' 0.75',
#  ' 3.5',
#  ' cup',
#  '84',
#  ' all purpose flour',
#  ' 5.4 cups all purpose flour',
#  ' E_26',
#  ' 0.875',
#  ' 5.4',
#  ' cup',
#  '85',
#  ' all purpose flour',
#  ' 2.0 cups all purpose flour',
#  ' E_362',
#  ' 0.625',
#  ' 2',
#  ' cup',
#  '86',
#  ' all purpose flour',
#  ' 3.42857142857 cups all purpose flour',
#  ' E_375',
#  ' 0.75',
#  ' 3.428571429',
#  ' cup',
#  '87',
#  ' all purpose flour',
#  ' 4.36363636364 cups plain all purpose flour',
#  ' E_399',
#  ' 1',
#  ' 4.363636364',
#  ' cup',
#  '88',
#  ' all purpose flour',
#  ' 0.32 cup all purpose flour',
#  ' E_509',
#  ' 0.75',
#  ' 0.32',
#  ' cup',
#  '89',
#  ' all purpose flour',
#  ' 2.4 cups all purpose flour',
#  ' E_79',
#  ' 0.75',
#  ' 2.4',
#  ' cup',
#  '90',
#  ' all purpose flour',
#  ' 2.88 cups all purpose flour',
#  ' E_87',
#  ' 0.75',
#  ' 2.88',
#  ' cup',
#  '91',
#  ' all purpose flour',
#  ' 16.0 cups all purpose flour',
#  ' E_88',
#  ' 0.375',
#  ' 16',
#  ' cup',
#  '92',
#  ' all purpose flour',
#  ' 2.5 cups all purpose flour',
#  ' E_89',
#  ' 0.875',
#  ' 2.5',
#  ' cup',
#  '93',
#  ' all purpose flour',
#  ' 1.8 cups all purpose flour',
#  ' E_91',
#  ' 1',
#  ' 1.8',
#  ' cup',
#  '94',
#  ' all purpose flour',
#  ' 3.6 cups all purpose flour',
#  ' Misc_10',
#  ' NA',
#  ' 3.6',
#  ' cup',
#  '95',
#  ' all purpose flour',
#  ' 6.0 cups of all purpose flour',
#  ' Misc_101',
#  ' NA',
#  ' 6',
#  ' cup',
#  '96',
#  ' all purpose flour',
#  ' 7.0 cup 210 g flour',
#  ' Misc_102',
#  ' NA',
#  ' 7',
#  ' cup',
#  '97',
#  ' all purpose flour',
#  ' 3.33333333333 â\x81\x842 cups all purpose flour',
#  ' Misc_103',
#  ' NA',
#  ' 3.333333333',
#  ' cup',
#  '98',
#  ' all purpose flour',
#  ' 2.0 cups 6 1/2 oz./200 g unbleached all purpose flour',
#  ' Misc_104',
#  ' NA',
#  ' 2',
#  ' cup',
#  '99',
#  ' all purpose flour',
#  ' 8.0 cup plus 2 tbs. all purpose flour',
#  ' Misc_105',
#  ' NA',
#  ' 8',
#  ' cup',
#  '100',
#  ' all purpose flour',
#  ' 3.0 cups all purpose flour',
#  ' Misc_106',
#  ' NA',
#  ' 3',
#  ' cup',
#  '101',
#  ' all purpose flour',
#  ' 2.0 cups 6 1/2 oz./200 g unbleached all purpose flour',
#  ' Misc_107',
#  ' NA',
#  ' 2',
#  ' cup',
#  '102',
#  ' all purpose flour',
#  ' 2.5 cups all purpose flour',
#  ' Misc_108',
#  ' NA',
#  ' 2.5',
#  ' cup',
#  '103',
#  ' all purpose flour',
#  ' 4.0 cups flour',
#  ' Misc_109',
#  ' NA',
#  ' 4',
#  ' cup',
#  '104',
#  ' all purpose flour',
#  ' 1.8 cups all purpose flour',
#  ' Misc_11',
#  ' NA',
#  ' 1.8',
#  ' cup',
#  '105',
#  ' all purpose flour',
#  ' "18.75 ounces all purpose flour',
#  ' such as gold medal"',
#  ' Misc_110',
#  ' NA',
#  ' 2.34375',
#  ' cup',
#  '106',
#  ' all purpose flour',
#  ' 2.93333333333 cups all purpose flour 350g',
#  ' Misc_111',
#  ' NA',
#  ' 2.933333333',
#  ' cup',
#  '107',
#  ' all purpose flour',
#  ' 5.33333333333 cups plus 3 tablespoons all purpose flour',
#  ' Misc_112',
#  ' NA',
#  ' 5.333333333',
#  ' cup',
#  '108',
#  ' all purpose flour',
#  ' 2.85714285714 cups all purpose flour do not sift',
#  ' Misc_113',
#  ' NA',
#  ' 2.857142857',
#  ' cup',
#  '109',
#  ' all purpose flour',
#  ' 3.6 cups all purpose flour',
#  ' Misc_114',
#  ' NA',
#  ' 3.6',
#  ' cup',
#  '110',
#  ' all purpose flour',
#  ' 3.0 cups all purpose flour see notes below',
#  ' Misc_12',
#  ' NA',
#  ' 3',
#  ' cup',
#  '111',
#  ' all purpose flour',
#  ' 3.0 cups all purpose flour',
#  ' Misc_13',
#  ' NA',
#  ' 3',
#  ' cup',
#  '112',
#  ' all purpose flour',
#  ' 5.53846153846 cups 380 grams all purpose flour',
#  ' Misc_14',
#  ' NA',
#  ' 5.538461538',
#  ' cup',
#  '113',
#  ' all purpose flour',
#  ' 2.93333333333 cups all purpose flour 350g',
#  ' Misc_15',
#  ' NA',
#  ' 2.933333333',
#  ' cup',
#  '114',
#  ' all purpose flour',
#  ' 2.83333333333 cups all purpose flour',
#  ' Misc_16',
#  ' NA',
#  ' 2.833333333',
#  ' cup',
#  '115',
#  ' all purpose flour',
#  ' 4.25 cups all purpose flour',
#  ' Misc_17',
#  ' NA',
#  ' 4.25',
#  ' cup',
#  '116',
#  ' all purpose flour',
#  ' 2.66666666667 cups king arthur unbleached all purpose flour',
#  ' Misc_18',
#  ' NA',
#  ' 2.666666667',
#  ' cup',
#  '117',
#  ' all purpose flour',
#  ' 4.875 cups all purpose flour 415g',
#  ' Misc_19',
#  ' NA',
#  ' 4.875',
#  ' cup',
#  '118',
#  ' all purpose flour',
#  ' 1.5 cups all purpose flour 1.5 cups',
#  ' Misc_2',
#  ' NA',
#  ' 1.5',
#  ' cup',
#  '119',
#  ' all purpose flour',
#  ' 5.0 cups all purpose flour',
#  ' Misc_20',
#  ' NA',
#  ' 5',
#  ' cup',
#  '120',
#  ' all purpose flour',
#  ' 2.33333333333 cups plus 1 tablespoon all purpose flour',
#  ' Misc_22',
#  ' NA',
#  ' 2.333333333',
#  ' cup',
#  '121',
#  ' all purpose flour',
#  ' 4.0 cups plus 3 tablespoons all purpose flour',
#  ' Misc_23',
#  ' NA',
#  ' 4',
#  ' cup',
#  '122',
#  ' all purpose flour',
#  ' 2.0 cups all purpose flour',
#  ' Misc_24',
#  ' NA',
#  ' 2',
#  ' cup',
#  '123',
#  ' all purpose flour',
#  ' 5.33333333333 cups all purpose flour',
#  ' Misc_26',
#  ' NA',
#  ' 5.333333333',
#  ' cup',
#  '124',
#  ' all purpose flour',
#  ' 5.0 cups 325 grams all purpose flour',
#  ' Misc_27',
#  ' NA',
#  ' 5',
#  ' cup',
#  '125',
#  ' all purpose flour',
#  ' 5.0 cups all purpose flour',
#  ' Misc_28',
#  ' NA',
#  ' 5',
#  ' cup',
#  '126',
#  ' all purpose flour',
#  ' 2.66666666667 cups plus 2.66666666667 tablespoons flour',
#  ' Misc_29',
#  ' NA',
#  ' 2.666666667',
#  ' cup',
#  '127',
#  ' all purpose flour',
#  ' 0.0 cup/50.0 grams all purpose flour',
#  ' Misc_3',
#  ' NA',
#  ' 0',
#  ' cup',
#  '128',
#  ' all purpose flour',
#  ' 5.4 cups all purpose flour',
#  ' Misc_30',
#  ' NA',
#  ' 5.4',
#  ' cup',
#  '129',
#  ' all purpose flour',
#  ' 2.0 cups all purpose flour',
#  ' Misc_31',
#  ' NA',
#  ' 2',
#  ' cup',
#  '130',
#  ' all purpose flour',
#  ' 6.0 cups flour',
#  ' Misc_32',
#  ' NA',
#  ' 6',
#  ' cup',
#  '131',
#  ' all purpose flour',
#  ' 2.64 cup all purpose flour',
#  ' Misc_33',
#  ' NA',
#  ' 2.64',
#  ' cup',
#  '132',
#  ' all purpose flour',
#  ' 8.57142857143 cups 12 1/2oz/375g all purpose flour/plain flour',
#  ' Misc_34',
#  ' NA',
#  ' 8.571428571',
#  ' cup',
#  '133',
#  ' all purpose flour',
#  ' 2.46153846154 cups all purpose flour',
#  ' Misc_35',
#  ' NA',
#  ' 2.461538462',
#  ' cup',
#  '134',
#  ' all purpose flour',
#  ' 5.25 cups flour',
#  ' Misc_36',
#  ' NA',
#  ' 5.25',
#  ' cup',
#  '135',
#  ' all purpose flour',
#  ' 4.0 cups all purpose flour',
#  ' Misc_37',
#  ' NA',
#  ' 4',
#  ' cup',
#  '136',
#  ' all purpose flour',
#  ' 5.2 cups flour',
#  ' Misc_38',
#  ' NA',
#  ' 5.2',
#  ' cup',
#  '137',
#  ' all purpose flour',
#  ' 1.6 1/4 cups all purpose flour',
#  ' Misc_39',
#  ' NA',
#  ' 1.6',
#  ' cup',
#  '138',
#  ' all purpose flour',
#  ' 9.6 cups/256 grams all purpose flour',
#  ' Misc_4',
#  ' NA',
#  ' 9.6',
#  ' cup',
#  '139',
#  ' all purpose flour',
#  ' 2.25 cups 295 grams all purpose flour',
#  ' Misc_40',
#  ' NA',
#  ' 2.25',
#  ' cup',
#  '140',
#  ' all purpose flour',
#  ' 2.7 cups all purpose flour',
#  ' Misc_41',
#  ' NA',
#  ' 2.7',
#  ' cup',
#  '141',
#  ' all purpose flour',
#  ' 4.8 cups flour',
#  ' Misc_42',
#  ' NA',
#  ' 4.8',
#  ' cup',
#  '142',
#  ' all purpose flour',
#  ' 2.52631578947 and 3/4 cups 345 grams all purpose flour spooned & leveled',
#  ' Misc_43',
#  ' NA',
#  ' 2.526315789',
#  ' cup',
#  '143',
#  ' all purpose flour',
#  ' 4.0 cups plus 4.0 tbsp all purpose flour',
#  ' Misc_44',
#  ' NA',
#  ...]

# %%
len(data_lines)
# Out:
# 14079

# %% [markdown]
# After cleaning the lines, they realized that not all the ingredients had 7 lines. Some text occupies multiple lines.

# %%
list_list_ingredients = []

for i in range(len(data_lines)):
    if data_lines[i].startswith(' '):
        list_list_ingredients[-1].append(data_lines[i])
    else:
        list_list_ingredients.append([])
        list_list_ingredients[-1].append(data_lines[i])

# %%
ingredient_lengths = [ len(list_ingredients) for list_ingredients in list_list_ingredients ]

for i in range(len(ingredient_lengths)):
    if ingredient_lengths[i] != 7:
        print("Not all ingredients occupy 7 lines.")
        print(list_list_ingredients[i])
        break
# Out:
# Not all ingredients occupy 7 lines.
# ['105', ' all purpose flour', ' "18.75 ounces all purpose flour', ' such as gold medal"', ' Misc_110', ' NA', ' 2.34375', ' cup']

# %% [markdown]
# The researchers noticed that the initial line element of the line for the ingredient starts with a quotation mark. Then, the last line element of the line for the ingredient ends with a quotation mark.<br><br>
# Thus, they kept this principle when iterating through every list of lines for ingredients.<br>

# %%
for i in range(len(ingredient_lengths)-1, -1, -1):
    if ingredient_lengths[i] != 7:
        num_of_lines = len(list_list_ingredients[i])
        for j in range(num_of_lines-1, 2, -1):
            if list_list_ingredients[i][j][-1] == '"' and list_list_ingredients[i][j][0] != '"':
                list_list_ingredients[i][j-1] += list_list_ingredients[i][j]
                del list_list_ingredients[i][j]

# %%
ingredient_lengths = [ len(list_ingredients) for list_ingredients in list_list_ingredients ]

for i in range(len(ingredient_lengths)):
    if ingredient_lengths[i] != 7:
        print("Not all ingredients occupy 7 lines.")
        print(list_list_ingredients[i])
        break

# %%
list_list_ingredients[104]
# Out:
# ['105',
#  ' all purpose flour',
#  ' "18.75 ounces all purpose flour such as gold medal"',
#  ' Misc_110',
#  ' NA',
#  ' 2.34375',
#  ' cup']

# %% [markdown]
# The researchers also had to remove the quotation marks between the texts.

# %%
for i in range(len(list_list_ingredients)):
    if list_list_ingredients[i][2].startswith(' "'):
        line = list_list_ingredients[i][2]
        list_list_ingredients[i][2] = re.findall(r'"(.+?)"', line)[0]

# %%
list_list_ingredients[104]
# Out:
# ['105',
#  ' all purpose flour',
#  '18.75 ounces all purpose flour such as gold medal',
#  ' Misc_110',
#  ' NA',
#  ' 2.34375',
#  ' cup']

# %% [markdown]
# ## Putting Lines into List of Dictionaries

# %%
ingredient_dicts = []

import numpy as np

for ingredient in list_list_ingredients:
    try:
        ingredient_dicts.append({
            "entry_no": int(ingredient[0]),
            "ingredient": ingredient[1].strip(),
            "text": ingredient[2].strip(),
            "recipe_index": ingredient[3].strip(),
            "rating": float(ingredient[4]),
            "quantity": float(ingredient[5].strip()),
            "unit": ingredient[6].strip()
        })
    except:
        ingredient_dicts.append({
            "entry_no": int(ingredient[0]),
            "ingredient": ingredient[1].strip(),
            "text": ingredient[2].strip(),
            "recipe_index": ingredient[3].strip(),
            "rating": np.nan,
            "quantity": float(ingredient[5].strip()),
            "unit": ingredient[6].strip()
        })

# %%
ingredient_dicts[200:]
# Out:
# [{'entry_no': 201,
#   'ingredient': 'baking powder',
#   'text': '0.7384615384615385 teaspoons baking powder',
#   'recipe_index': 'AR_101',
#   'rating': 0.6,
#   'quantity': 0.738461538,
#   'unit': 'teaspoon'},
#  {'entry_no': 202,
#   'ingredient': 'baking powder',
#   'text': '1.0 teaspoon baking powder',
#   'recipe_index': 'AR_119',
#   'rating': 0.845714283,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 203,
#   'ingredient': 'baking powder',
#   'text': '0.6666666666666666 teaspoon baking powder',
#   'recipe_index': 'AR_14',
#   'rating': 0.90666666,
#   'quantity': 0.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 204,
#   'ingredient': 'baking powder',
#   'text': '1.1428571428571428 teaspoons baking powder',
#   'recipe_index': 'AR_16',
#   'rating': 0.85882349,
#   'quantity': 1.142857143,
#   'unit': 'teaspoon'},
#  {'entry_no': 205,
#   'ingredient': 'baking powder',
#   'text': '1.3333333333333333 teaspoon baking powder',
#   'recipe_index': 'AR_169',
#   'rating': 0.873728848,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 206,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'AR_256',
#   'rating': 0.870253181,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 207,
#   'ingredient': 'baking powder',
#   'text': '0.5 teaspoon baking powder',
#   'recipe_index': 'AR_26',
#   'rating': 0.9,
#   'quantity': 0.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 208,
#   'ingredient': 'baking powder',
#   'text': '2.6666666666666665 teaspoons baking powder',
#   'recipe_index': 'AR_27',
#   'rating': 0.876923084,
#   'quantity': 2.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 209,
#   'ingredient': 'baking powder',
#   'text': '0.25 teaspoon baking powder',
#   'recipe_index': 'AR_280',
#   'rating': nan,
#   'quantity': 0.25,
#   'unit': 'teaspoon'},
#  {'entry_no': 210,
#   'ingredient': 'baking powder',
#   'text': '0.8 teaspoon baking powder',
#   'recipe_index': 'AR_32',
#   'rating': 0.830769253,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 211,
#   'ingredient': 'baking powder',
#   'text': '1.0 teaspoon baking powder',
#   'recipe_index': 'AR_39',
#   'rating': 0.6,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 212,
#   'ingredient': 'baking powder',
#   'text': '1.0 teaspoon baking powder',
#   'recipe_index': 'AR_4',
#   'rating': 0.922985077,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 213,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'AR_47',
#   'rating': 0.7125,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 214,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'AR_48',
#   'rating': 0.677777767,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 215,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoons baking powder',
#   'recipe_index': 'AR_50',
#   'rating': 0.66500001,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 216,
#   'ingredient': 'baking powder',
#   'text': '1.0 teaspoon baking powder',
#   'recipe_index': 'AR_57',
#   'rating': 0.595505619,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 217,
#   'ingredient': 'baking powder',
#   'text': '1.0 teaspoon baking powder',
#   'recipe_index': 'AR_7',
#   'rating': 0.896335125,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 218,
#   'ingredient': 'baking powder',
#   'text': '0.8 teaspoon baking powder',
#   'recipe_index': 'AR_70',
#   'rating': 0.91003809,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 219,
#   'ingredient': 'baking powder',
#   'text': '0.5 teaspoon baking powder',
#   'recipe_index': 'AR_78',
#   'rating': 0.915186214,
#   'quantity': 0.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 220,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'AR_79',
#   'rating': 0.633333349,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 221,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'AR_84',
#   'rating': 0.905737686,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 222,
#   'ingredient': 'baking powder',
#   'text': '1.6 teaspoon baking powder',
#   'recipe_index': 'AR_95',
#   'rating': 0.844067764,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 223,
#   'ingredient': 'baking powder',
#   'text': '1.2 teaspoon baking powder',
#   'recipe_index': 'E_21',
#   'rating': 0.75,
#   'quantity': 1.2,
#   'unit': 'teaspoon'},
#  {'entry_no': 224,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'E_215',
#   'rating': 0.875,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 225,
#   'ingredient': 'baking powder',
#   'text': '1.33333333333 teaspoon baking powder',
#   'recipe_index': 'E_362',
#   'rating': 0.625,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 226,
#   'ingredient': 'baking powder',
#   'text': '0.545454545455 teaspoon baking powder',
#   'recipe_index': 'E_399',
#   'rating': 1.0,
#   'quantity': 0.545454545,
#   'unit': 'teaspoon'},
#  {'entry_no': 227,
#   'ingredient': 'baking powder',
#   'text': '6.0 teaspoons baking powder',
#   'recipe_index': 'Misc_1',
#   'rating': nan,
#   'quantity': 6.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 228,
#   'ingredient': 'baking powder',
#   'text': '4.0 teaspoons baking powder',
#   'recipe_index': 'Misc_100',
#   'rating': nan,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 229,
#   'ingredient': 'baking powder',
#   'text': '4.0 teaspoons baking powder',
#   'recipe_index': 'Misc_109',
#   'rating': nan,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 230,
#   'ingredient': 'baking powder',
#   'text': '0.75 teaspoon baking powder',
#   'recipe_index': 'Misc_110',
#   'rating': nan,
#   'quantity': 0.75,
#   'unit': 'teaspoon'},
#  {'entry_no': 231,
#   'ingredient': 'baking powder',
#   'text': '1.0 teaspoon baking powder',
#   'recipe_index': 'Misc_17',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 232,
#   'ingredient': 'baking powder',
#   'text': '1.5 teaspoon baking powder',
#   'recipe_index': 'Misc_19',
#   'rating': nan,
#   'quantity': 1.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 233,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'Misc_20',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 234,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'Misc_32',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 235,
#   'ingredient': 'baking powder',
#   'text': '2.25 tsp baking powder',
#   'recipe_index': 'Misc_36',
#   'rating': nan,
#   'quantity': 2.25,
#   'unit': 'teaspoon'},
#  {'entry_no': 236,
#   'ingredient': 'baking powder',
#   'text': '2.4 teaspoons baking powder',
#   'recipe_index': 'Misc_49',
#   'rating': nan,
#   'quantity': 2.4,
#   'unit': 'teaspoon'},
#  {'entry_no': 237,
#   'ingredient': 'baking powder',
#   'text': '0.571428571429 teaspoon baking powder',
#   'recipe_index': 'Misc_55',
#   'rating': nan,
#   'quantity': 0.571428571,
#   'unit': 'teaspoon'},
#  {'entry_no': 238,
#   'ingredient': 'baking powder',
#   'text': '2.0 tsp baking powder',
#   'recipe_index': 'Misc_60',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 239,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'Misc_62',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 240,
#   'ingredient': 'baking powder',
#   'text': '1.77777777778 teaspoon baking powder',
#   'recipe_index': 'Misc_63',
#   'rating': nan,
#   'quantity': 1.777777778,
#   'unit': 'teaspoon'},
#  {'entry_no': 241,
#   'ingredient': 'baking powder',
#   'text': '1.6 teaspoon baking powder',
#   'recipe_index': 'Misc_7',
#   'rating': nan,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 242,
#   'ingredient': 'baking powder',
#   'text': '0.666666666667 teaspoon baking powder',
#   'recipe_index': 'Misc_70',
#   'rating': nan,
#   'quantity': 0.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 243,
#   'ingredient': 'baking powder',
#   'text': '3.69230769231 teaspoon baking powder',
#   'recipe_index': 'Misc_71',
#   'rating': nan,
#   'quantity': 3.692307692,
#   'unit': 'teaspoon'},
#  {'entry_no': 244,
#   'ingredient': 'baking powder',
#   'text': '1.0 tsp baking powder',
#   'recipe_index': 'Misc_73',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 245,
#   'ingredient': 'baking powder',
#   'text': '1.33333333333 tsp. baking powder',
#   'recipe_index': 'Misc_74',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 246,
#   'ingredient': 'baking powder',
#   'text': '2.66666666667 teaspoons baking powder',
#   'recipe_index': 'Misc_75',
#   'rating': nan,
#   'quantity': 2.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 247,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoon baking powder',
#   'recipe_index': 'Misc_76',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 248,
#   'ingredient': 'baking powder',
#   'text': '1.14285714286 teaspoon baking powder',
#   'recipe_index': 'Misc_77',
#   'rating': nan,
#   'quantity': 1.142857143,
#   'unit': 'teaspoon'},
#  {'entry_no': 249,
#   'ingredient': 'baking powder',
#   'text': '0.872727272727 teaspoon baking powder',
#   'recipe_index': 'Misc_8',
#   'rating': nan,
#   'quantity': 0.872727273,
#   'unit': 'teaspoon'},
#  {'entry_no': 250,
#   'ingredient': 'baking powder',
#   'text': '2.0 teaspoons baking powder',
#   'recipe_index': 'Misc_94',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 251,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_1',
#   'rating': 0.920724583,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 252,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'AR_10',
#   'rating': 0.905162048,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 253,
#   'ingredient': 'baking soda',
#   'text': '0.7384615384615385 teaspoons baking soda',
#   'recipe_index': 'AR_101',
#   'rating': 0.6,
#   'quantity': 0.738461538,
#   'unit': 'teaspoon'},
#  {'entry_no': 254,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_102',
#   'rating': 0.9375,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 255,
#   'ingredient': 'baking soda',
#   'text': '0.9 teaspoons baking soda',
#   'recipe_index': 'AR_103',
#   'rating': 0.88125,
#   'quantity': 0.9,
#   'unit': 'teaspoon'},
#  {'entry_no': 256,
#   'ingredient': 'baking soda',
#   'text': '4.0 teaspoon baking soda',
#   'recipe_index': 'AR_107',
#   'rating': 0.927272701,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 257,
#   'ingredient': 'baking soda',
#   'text': '0.5714285714285714 teaspoon baking soda',
#   'recipe_index': 'AR_108',
#   'rating': 0.867741966,
#   'quantity': 0.571428571,
#   'unit': 'teaspoon'},
#  {'entry_no': 258,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoons baking soda',
#   'recipe_index': 'AR_109',
#   'rating': 0.871794891,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 259,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_11',
#   'rating': 0.902891922,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 260,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_110',
#   'rating': 0.868292713,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 261,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_111',
#   'rating': 1.0,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 262,
#   'ingredient': 'baking soda',
#   'text': '0.25 teaspoon baking soda',
#   'recipe_index': 'AR_116',
#   'rating': 0.847999954,
#   'quantity': 0.25,
#   'unit': 'teaspoon'},
#  {'entry_no': 263,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'AR_118',
#   'rating': 0.830769253,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 264,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_119',
#   'rating': 0.845714283,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 265,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_12',
#   'rating': 0.873469353,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 266,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_128',
#   'rating': 0.714285707,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 267,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_13',
#   'rating': 0.909016418,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 268,
#   'ingredient': 'baking soda',
#   'text': '0.6666666666666666 teaspoon baking soda',
#   'recipe_index': 'AR_14',
#   'rating': 0.90666666,
#   'quantity': 0.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 269,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_140',
#   'rating': 0.584615374,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 270,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_141',
#   'rating': 0.784615374,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 271,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_142',
#   'rating': 0.671428585,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 272,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_144',
#   'rating': 0.442857122,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 273,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_15',
#   'rating': 0.924302769,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 274,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoons baking soda',
#   'recipe_index': 'AR_155',
#   'rating': 0.931135178,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 275,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_156',
#   'rating': 0.924294472,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 276,
#   'ingredient': 'baking soda',
#   'text': '1.1428571428571428 teaspoons baking soda',
#   'recipe_index': 'AR_16',
#   'rating': 0.85882349,
#   'quantity': 1.142857143,
#   'unit': 'teaspoon'},
#  {'entry_no': 277,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_164',
#   'rating': 0.917012405,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 278,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_169',
#   'rating': 0.873728848,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 279,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_19',
#   'rating': 0.880000019,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 280,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_196',
#   'rating': 0.785929632,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 281,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_197',
#   'rating': 0.706521749,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 282,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_2',
#   'rating': 0.937981987,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 283,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoons baking soda',
#   'recipe_index': 'AR_21',
#   'rating': 0.881944466,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 284,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_218',
#   'rating': 0.877419376,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 285,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_256',
#   'rating': 0.870253181,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 286,
#   'ingredient': 'baking soda',
#   'text': '0.5 teaspoon baking soda',
#   'recipe_index': 'AR_26',
#   'rating': 0.9,
#   'quantity': 0.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 287,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoons baking soda',
#   'recipe_index': 'AR_28',
#   'rating': 0.873333359,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 288,
#   'ingredient': 'baking soda',
#   'text': '0.75 teaspoon baking soda',
#   'recipe_index': 'AR_280',
#   'rating': nan,
#   'quantity': 0.75,
#   'unit': 'teaspoon'},
#  {'entry_no': 289,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_3',
#   'rating': 0.917986774,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 290,
#   'ingredient': 'baking soda',
#   'text': '0.5 teaspoon baking soda',
#   'recipe_index': 'AR_30',
#   'rating': 0.859829044,
#   'quantity': 0.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 291,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'AR_32',
#   'rating': 0.830769253,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 292,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_33',
#   'rating': 0.826666641,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 293,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_35',
#   'rating': 0.843636322,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 294,
#   'ingredient': 'baking soda',
#   'text': '2.6666666666666665 teaspoons baking soda',
#   'recipe_index': 'AR_37',
#   'rating': 0.8,
#   'quantity': 2.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 295,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_39',
#   'rating': 0.6,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 296,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_4',
#   'rating': 0.922985077,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 297,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_43',
#   'rating': 0.828866005,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 298,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_45',
#   'rating': 0.821052647,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 299,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_49',
#   'rating': 0.592592573,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 300,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_5',
#   'rating': 0.937341785,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 301,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoons baking soda',
#   'recipe_index': 'AR_50',
#   'rating': 0.66500001,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 302,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_53',
#   'rating': 0.692473125,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 303,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_54',
#   'rating': 0.723741007,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 304,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_55',
#   'rating': 0.385714293,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 305,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_57',
#   'rating': 0.595505619,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 306,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_66',
#   'rating': 0.902002907,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 307,
#   'ingredient': 'baking soda',
#   'text': '1.5 teaspoon baking soda',
#   'recipe_index': 'AR_67',
#   'rating': 0.939130402,
#   'quantity': 1.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 308,
#   'ingredient': 'baking soda',
#   'text': '1.5 teaspoon baking soda',
#   'recipe_index': 'AR_69',
#   'rating': 0.920792103,
#   'quantity': 1.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 309,
#   'ingredient': 'baking soda',
#   'text': '0.6666666666666666 teaspoon baking soda',
#   'recipe_index': 'AR_7',
#   'rating': 0.896335125,
#   'quantity': 0.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 310,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'AR_70',
#   'rating': 0.91003809,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 311,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_78',
#   'rating': 0.915186214,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 312,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_8',
#   'rating': 0.942446041,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 313,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_84',
#   'rating': 0.905737686,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 314,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'AR_88',
#   'rating': 0.955555534,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 315,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'AR_89',
#   'rating': 0.909890079,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 316,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_90',
#   'rating': 0.902608681,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 317,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'AR_91',
#   'rating': 0.928301907,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 318,
#   'ingredient': 'baking soda',
#   'text': '1.6 teaspoon baking soda',
#   'recipe_index': 'AR_95',
#   'rating': 0.844067764,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 319,
#   'ingredient': 'baking soda',
#   'text': '1.3333333333333333 teaspoon baking soda',
#   'recipe_index': 'AR_96',
#   'rating': 0.818181801,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 320,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'AR_97',
#   'rating': 0.933333302,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 321,
#   'ingredient': 'baking soda',
#   'text': '0.04 cup baking soda',
#   'recipe_index': 'AR_98',
#   'rating': 0.90666666,
#   'quantity': 1.920003072,
#   'unit': 'teaspoon'},
#  {'entry_no': 322,
#   'ingredient': 'baking soda',
#   'text': '0.5 teaspoon baking soda',
#   'recipe_index': 'E_133',
#   'rating': 0.75,
#   'quantity': 0.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 323,
#   'ingredient': 'baking soda',
#   'text': '0.0888888888889 teaspoon baking soda',
#   'recipe_index': 'E_146',
#   'rating': 0.5,
#   'quantity': 0.088888889,
#   'unit': 'teaspoon'},
#  {'entry_no': 324,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoons baking soda',
#   'recipe_index': 'E_197',
#   'rating': 0.875,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 325,
#   'ingredient': 'baking soda',
#   'text': '0.5 teaspoon baking soda',
#   'recipe_index': 'E_215',
#   'rating': 0.875,
#   'quantity': 0.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 326,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoon baking soda',
#   'recipe_index': 'E_220',
#   'rating': 0.75,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 327,
#   'ingredient': 'baking soda',
#   'text': '2.57142857143 teaspoons baking soda',
#   'recipe_index': 'E_230',
#   'rating': 0.875,
#   'quantity': 2.571428571,
#   'unit': 'teaspoon'},
#  {'entry_no': 328,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'E_258',
#   'rating': 0.75,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 329,
#   'ingredient': 'baking soda',
#   'text': '2.4 teaspoon baking soda',
#   'recipe_index': 'E_26',
#   'rating': 0.875,
#   'quantity': 2.4,
#   'unit': 'teaspoon'},
#  {'entry_no': 330,
#   'ingredient': 'baking soda',
#   'text': '0.333333333333 teaspoon baking soda',
#   'recipe_index': 'E_362',
#   'rating': 0.625,
#   'quantity': 0.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 331,
#   'ingredient': 'baking soda',
#   'text': '1.14285714286 teaspoon baking soda',
#   'recipe_index': 'E_375',
#   'rating': 0.75,
#   'quantity': 1.142857143,
#   'unit': 'teaspoon'},
#  {'entry_no': 332,
#   'ingredient': 'baking soda',
#   'text': '0.545454545455 teaspoon baking soda',
#   'recipe_index': 'E_399',
#   'rating': 1.0,
#   'quantity': 0.545454545,
#   'unit': 'teaspoon'},
#  {'entry_no': 333,
#   'ingredient': 'baking soda',
#   'text': '0.16 teaspoon baking soda',
#   'recipe_index': 'E_509',
#   'rating': 0.75,
#   'quantity': 0.16,
#   'unit': 'teaspoon'},
#  {'entry_no': 334,
#   'ingredient': 'baking soda',
#   'text': '1.6 teaspoon baking soda',
#   'recipe_index': 'E_79',
#   'rating': 0.75,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 335,
#   'ingredient': 'baking soda',
#   'text': '0.48 teaspoon baking soda',
#   'recipe_index': 'E_87',
#   'rating': 0.75,
#   'quantity': 0.48,
#   'unit': 'teaspoon'},
#  {'entry_no': 336,
#   'ingredient': 'baking soda',
#   'text': '4.0 teaspoon baking soda',
#   'recipe_index': 'E_88',
#   'rating': 0.375,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 337,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'E_89',
#   'rating': 0.875,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 338,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'E_91',
#   'rating': 1.0,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 339,
#   'ingredient': 'baking soda',
#   'text': '5.0 teaspoons baking soda',
#   'recipe_index': 'Misc_1',
#   'rating': nan,
#   'quantity': 5.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 340,
#   'ingredient': 'baking soda',
#   'text': '1.2 teaspoon baking soda',
#   'recipe_index': 'Misc_10',
#   'rating': nan,
#   'quantity': 1.2,
#   'unit': 'teaspoon'},
#  {'entry_no': 341,
#   'ingredient': 'baking soda',
#   'text': '3.33333333333 teaspoons baking soda',
#   'recipe_index': 'Misc_100',
#   'rating': nan,
#   'quantity': 3.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 342,
#   'ingredient': 'baking soda',
#   'text': '1.5 teaspoon of baking soda',
#   'recipe_index': 'Misc_101',
#   'rating': nan,
#   'quantity': 1.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 343,
#   'ingredient': 'baking soda',
#   'text': '4.0 tsp 5 ml baking soda',
#   'recipe_index': 'Misc_102',
#   'rating': nan,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 344,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoons baking soda',
#   'recipe_index': 'Misc_103',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 345,
#   'ingredient': 'baking soda',
#   'text': '1.6 tsp. baking soda',
#   'recipe_index': 'Misc_104',
#   'rating': nan,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 346,
#   'ingredient': 'baking soda',
#   'text': '4.0 tsp. baking soda',
#   'recipe_index': 'Misc_105',
#   'rating': nan,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 347,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 tsp. baking soda',
#   'recipe_index': 'Misc_106',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 348,
#   'ingredient': 'baking soda',
#   'text': '1.6 tsp. baking soda',
#   'recipe_index': 'Misc_107',
#   'rating': nan,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 349,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_108',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 350,
#   'ingredient': 'baking soda',
#   'text': '4.0 teaspoons baking soda',
#   'recipe_index': 'Misc_109',
#   'rating': nan,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 351,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'Misc_11',
#   'rating': nan,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 352,
#   'ingredient': 'baking soda',
#   'text': '1.5 teaspoon baking soda',
#   'recipe_index': 'Misc_110',
#   'rating': nan,
#   'quantity': 1.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 353,
#   'ingredient': 'baking soda',
#   'text': '1.06666666667 teaspoon baking soda',
#   'recipe_index': 'Misc_111',
#   'rating': nan,
#   'quantity': 1.066666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 354,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_112',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 355,
#   'ingredient': 'baking soda',
#   'text': '1.14285714286 teaspoon baking soda',
#   'recipe_index': 'Misc_113',
#   'rating': nan,
#   'quantity': 1.142857143,
#   'unit': 'teaspoon'},
#  {'entry_no': 356,
#   'ingredient': 'baking soda',
#   'text': '1.6 teaspoon baking soda',
#   'recipe_index': 'Misc_114',
#   'rating': nan,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 357,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_12',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 358,
#   'ingredient': 'baking soda',
#   'text': '0.666666666667 teaspoon baking soda',
#   'recipe_index': 'Misc_13',
#   'rating': nan,
#   'quantity': 0.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 359,
#   'ingredient': 'baking soda',
#   'text': '1.84615384615 teaspoon baking soda',
#   'recipe_index': 'Misc_14',
#   'rating': nan,
#   'quantity': 1.846153846,
#   'unit': 'teaspoon'},
#  {'entry_no': 360,
#   'ingredient': 'baking soda',
#   'text': '1.06666666667 teaspoon baking soda',
#   'recipe_index': 'Misc_15',
#   'rating': nan,
#   'quantity': 1.066666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 361,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoons baking soda',
#   'recipe_index': 'Misc_16',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 362,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'Misc_17',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 363,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoon baking soda',
#   'recipe_index': 'Misc_18',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 364,
#   'ingredient': 'baking soda',
#   'text': '1.5 teaspoon baking soda',
#   'recipe_index': 'Misc_19',
#   'rating': nan,
#   'quantity': 1.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 365,
#   'ingredient': 'baking soda',
#   'text': '0.5 teaspoon baking soda 0.5 teaspoon',
#   'recipe_index': 'Misc_2',
#   'rating': nan,
#   'quantity': 0.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 366,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_20',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 367,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_21',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 368,
#   'ingredient': 'baking soda',
#   'text': '0.75 teaspoon baking soda',
#   'recipe_index': 'Misc_22',
#   'rating': nan,
#   'quantity': 0.75,
#   'unit': 'teaspoon'},
#  {'entry_no': 369,
#   'ingredient': 'baking soda',
#   'text': '1.5 teaspoon baking soda',
#   'recipe_index': 'Misc_23',
#   'rating': nan,
#   'quantity': 1.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 370,
#   'ingredient': 'baking soda',
#   'text': '2.0 â\x81\x844 teaspoon baking soda',
#   'recipe_index': 'Misc_24',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 371,
#   'ingredient': 'baking soda',
#   'text': '2.0 tsp. baking soda',
#   'recipe_index': 'Misc_25',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 372,
#   'ingredient': 'baking soda',
#   'text': '2.5 teaspoons baking soda',
#   'recipe_index': 'Misc_26',
#   'rating': nan,
#   'quantity': 2.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 373,
#   'ingredient': 'baking soda',
#   'text': '2.5 teaspoons baking soda',
#   'recipe_index': 'Misc_27',
#   'rating': nan,
#   'quantity': 2.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 374,
#   'ingredient': 'baking soda',
#   'text': '2.5 teaspoons baking soda',
#   'recipe_index': 'Misc_28',
#   'rating': nan,
#   'quantity': 2.5,
#   'unit': 'teaspoon'},
#  {'entry_no': 375,
#   'ingredient': 'baking soda',
#   'text': '0.666666666667 teaspoon baking soda',
#   'recipe_index': 'Misc_29',
#   'rating': nan,
#   'quantity': 0.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 376,
#   'ingredient': 'baking soda',
#   'text': '2.4 teaspoon baking soda',
#   'recipe_index': 'Misc_30',
#   'rating': nan,
#   'quantity': 2.4,
#   'unit': 'teaspoon'},
#  {'entry_no': 377,
#   'ingredient': 'baking soda',
#   'text': '0.4 teaspoon baking soda',
#   'recipe_index': 'Misc_31',
#   'rating': nan,
#   'quantity': 0.4,
#   'unit': 'teaspoon'},
#  {'entry_no': 378,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_32',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 379,
#   'ingredient': 'baking soda',
#   'text': '0.96 tsp baking soda',
#   'recipe_index': 'Misc_33',
#   'rating': nan,
#   'quantity': 0.96,
#   'unit': 'teaspoon'},
#  {'entry_no': 380,
#   'ingredient': 'baking soda',
#   'text': '3.42857142857 teaspoon baking soda',
#   'recipe_index': 'Misc_34',
#   'rating': nan,
#   'quantity': 3.428571429,
#   'unit': 'teaspoon'},
#  {'entry_no': 381,
#   'ingredient': 'baking soda',
#   'text': '0.923076923077 teaspoon baking soda',
#   'recipe_index': 'Misc_35',
#   'rating': nan,
#   'quantity': 0.923076923,
#   'unit': 'teaspoon'},
#  {'entry_no': 382,
#   'ingredient': 'baking soda',
#   'text': '1.875 tsp baking soda',
#   'recipe_index': 'Misc_36',
#   'rating': nan,
#   'quantity': 1.875,
#   'unit': 'teaspoon'},
#  {'entry_no': 383,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoon baking soda',
#   'recipe_index': 'Misc_37',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 384,
#   'ingredient': 'baking soda',
#   'text': '1.6 teaspoon baking soda',
#   'recipe_index': 'Misc_38',
#   'rating': nan,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 385,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'Misc_39',
#   'rating': nan,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 386,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'Misc_40',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 387,
#   'ingredient': 'baking soda',
#   'text': '1.2 teaspoon baking soda',
#   'recipe_index': 'Misc_41',
#   'rating': nan,
#   'quantity': 1.2,
#   'unit': 'teaspoon'},
#  {'entry_no': 388,
#   'ingredient': 'baking soda',
#   'text': '1.6 teaspoon baking soda',
#   'recipe_index': 'Misc_42',
#   'rating': nan,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 389,
#   'ingredient': 'baking soda',
#   'text': '1.26315789474 teaspoon baking soda',
#   'recipe_index': 'Misc_43',
#   'rating': nan,
#   'quantity': 1.263157895,
#   'unit': 'teaspoon'},
#  {'entry_no': 390,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'Misc_44',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 391,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoon bakerâ\x80\x99s corner baking soda',
#   'recipe_index': 'Misc_45',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 392,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_46',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 393,
#   'ingredient': 'baking soda',
#   'text': '0.571428571429 teaspoon baking soda',
#   'recipe_index': 'Misc_47',
#   'rating': nan,
#   'quantity': 0.571428571,
#   'unit': 'teaspoon'},
#  {'entry_no': 394,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoon baking soda',
#   'recipe_index': 'Misc_48',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 395,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoons baking soda',
#   'recipe_index': 'Misc_49',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 396,
#   'ingredient': 'baking soda',
#   'text': '1.81818181818 teaspoons baking soda',
#   'recipe_index': 'Misc_5',
#   'rating': nan,
#   'quantity': 1.818181818,
#   'unit': 'teaspoon'},
#  {'entry_no': 397,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_50',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 398,
#   'ingredient': 'baking soda',
#   'text': '0.8 teaspoon baking soda',
#   'recipe_index': 'Misc_51',
#   'rating': nan,
#   'quantity': 0.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 399,
#   'ingredient': 'baking soda',
#   'text': '0.72 teaspoon baking soda',
#   'recipe_index': 'Misc_52',
#   'rating': nan,
#   'quantity': 0.72,
#   'unit': 'teaspoon'},
#  {'entry_no': 400,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'Misc_54',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 401,
#   'ingredient': 'baking soda',
#   'text': '0.571428571429 teaspoon baking soda',
#   'recipe_index': 'Misc_55',
#   'rating': nan,
#   'quantity': 0.571428571,
#   'unit': 'teaspoon'},
#  {'entry_no': 402,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_56',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 403,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'Misc_61',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 404,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_62',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 405,
#   'ingredient': 'baking soda',
#   'text': '0.888888888889 teaspoon baking soda',
#   'recipe_index': 'Misc_63',
#   'rating': nan,
#   'quantity': 0.888888889,
#   'unit': 'teaspoon'},
#  {'entry_no': 406,
#   'ingredient': 'baking soda',
#   'text': '1.2 teaspoon baking soda',
#   'recipe_index': 'Misc_64',
#   'rating': nan,
#   'quantity': 1.2,
#   'unit': 'teaspoon'},
#  {'entry_no': 407,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'Misc_65',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 408,
#   'ingredient': 'baking soda',
#   'text': '1.0 tsp. baking soda',
#   'recipe_index': 'Misc_67',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 409,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'Misc_68',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 410,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_69',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 411,
#   'ingredient': 'baking soda',
#   'text': '1.6 teaspoon baking soda',
#   'recipe_index': 'Misc_7',
#   'rating': nan,
#   'quantity': 1.6,
#   'unit': 'teaspoon'},
#  {'entry_no': 412,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoon baking soda',
#   'recipe_index': 'Misc_70',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 413,
#   'ingredient': 'baking soda',
#   'text': '1.0 tsp baking soda',
#   'recipe_index': 'Misc_73',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 414,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 tsp. baking soda',
#   'recipe_index': 'Misc_74',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 415,
#   'ingredient': 'baking soda',
#   'text': '2.66666666667 teaspoons baking soda',
#   'recipe_index': 'Misc_75',
#   'rating': nan,
#   'quantity': 2.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 416,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_76',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 417,
#   'ingredient': 'baking soda',
#   'text': '1.14285714286 teaspoon baking soda',
#   'recipe_index': 'Misc_77',
#   'rating': nan,
#   'quantity': 1.142857143,
#   'unit': 'teaspoon'},
#  {'entry_no': 418,
#   'ingredient': 'baking soda',
#   'text': '2.4 teaspoon | 5g baking soda',
#   'recipe_index': 'Misc_78',
#   'rating': nan,
#   'quantity': 2.4,
#   'unit': 'teaspoon'},
#  {'entry_no': 419,
#   'ingredient': 'baking soda',
#   'text': '3.42857142857 teaspoon baking soda',
#   'recipe_index': 'Misc_79',
#   'rating': nan,
#   'quantity': 3.428571429,
#   'unit': 'teaspoon'},
#  {'entry_no': 420,
#   'ingredient': 'baking soda',
#   'text': '0.872727272727 teaspoon baking soda',
#   'recipe_index': 'Misc_8',
#   'rating': nan,
#   'quantity': 0.872727273,
#   'unit': 'teaspoon'},
#  {'entry_no': 421,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_80',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 422,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoon baking soda',
#   'recipe_index': 'Misc_81',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 423,
#   'ingredient': 'baking soda',
#   'text': '1.71428571429 teaspoon baking soda',
#   'recipe_index': 'Misc_82',
#   'rating': nan,
#   'quantity': 1.714285714,
#   'unit': 'teaspoon'},
#  {'entry_no': 424,
#   'ingredient': 'baking soda',
#   'text': '1.0 tsp baking soda',
#   'recipe_index': 'Misc_83',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 425,
#   'ingredient': 'baking soda',
#   'text': '1.33333333333 teaspoon baking soda',
#   'recipe_index': 'Misc_85',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'teaspoon'},
#  {'entry_no': 426,
#   'ingredient': 'baking soda',
#   'text': '4.0 teaspoon baking soda',
#   'recipe_index': 'Misc_86',
#   'rating': nan,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 427,
#   'ingredient': 'baking soda',
#   'text': '4.0 tsp baking soda',
#   'recipe_index': 'Misc_87',
#   'rating': nan,
#   'quantity': 4.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 428,
#   'ingredient': 'baking soda',
#   'text': '1.71428571429 tsp baking soda',
#   'recipe_index': 'Misc_89',
#   'rating': nan,
#   'quantity': 1.714285714,
#   'unit': 'teaspoon'},
#  {'entry_no': 429,
#   'ingredient': 'baking soda',
#   'text': '1.0 teaspoon baking soda',
#   'recipe_index': 'Misc_9',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 430,
#   'ingredient': 'baking soda',
#   'text': '4.8 tsp. baking soda',
#   'recipe_index': 'Misc_90',
#   'rating': nan,
#   'quantity': 4.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 431,
#   'ingredient': 'baking soda',
#   'text': '1.0 tsp baking soda',
#   'recipe_index': 'Misc_91',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 432,
#   'ingredient': 'baking soda',
#   'text': '1.66666666667 teaspoons baking soda',
#   'recipe_index': 'Misc_94',
#   'rating': nan,
#   'quantity': 1.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 433,
#   'ingredient': 'baking soda',
#   'text': '1.66666666667 tsp. baking soda',
#   'recipe_index': 'Misc_95',
#   'rating': nan,
#   'quantity': 1.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 434,
#   'ingredient': 'baking soda',
#   'text': '1.8 tsp baking soda',
#   'recipe_index': 'Misc_96',
#   'rating': nan,
#   'quantity': 1.8,
#   'unit': 'teaspoon'},
#  {'entry_no': 435,
#   'ingredient': 'baking soda',
#   'text': '1.37142857143 tsp. baking soda',
#   'recipe_index': 'Misc_97',
#   'rating': nan,
#   'quantity': 1.371428571,
#   'unit': 'teaspoon'},
#  {'entry_no': 436,
#   'ingredient': 'baking soda',
#   'text': '2.0 teaspoon baking soda',
#   'recipe_index': 'Misc_98',
#   'rating': nan,
#   'quantity': 2.0,
#   'unit': 'teaspoon'},
#  {'entry_no': 437,
#   'ingredient': 'baking soda',
#   'text': '2.66666666667 teaspoon baking soda',
#   'recipe_index': 'Misc_99',
#   'rating': nan,
#   'quantity': 2.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 438,
#   'ingredient': 'bourbon',
#   'text': '4.0 tablespoons kentucky bourbon',
#   'recipe_index': 'AR_97',
#   'rating': 0.933333302,
#   'quantity': 4.0,
#   'unit': 'tablespoon'},
#  {'entry_no': 439,
#   'ingredient': 'bread flour',
#   'text': '0.177777777778 cups unbleached bread flour',
#   'recipe_index': 'E_146',
#   'rating': 0.5,
#   'quantity': 0.177777778,
#   'unit': 'cup'},
#  {'entry_no': 440,
#   'ingredient': 'bread flour',
#   'text': '6.66666666667 cups bread flour',
#   'recipe_index': 'Misc_1',
#   'rating': nan,
#   'quantity': 6.666666667,
#   'unit': 'cup'},
#  {'entry_no': 441,
#   'ingredient': 'bread flour',
#   'text': '4.44426666667 cups bread flour',
#   'recipe_index': 'Misc_100',
#   'rating': nan,
#   'quantity': 4.444266667,
#   'unit': 'cup'},
#  {'entry_no': 442,
#   'ingredient': 'bread flour',
#   'text': '24.0 ounces bread flour',
#   'recipe_index': 'Misc_21',
#   'rating': nan,
#   'quantity': 3.0,
#   'unit': 'cup'},
#  {'entry_no': 443,
#   'ingredient': 'bread flour',
#   'text': '1.33333333333 cup/150 grams bread flour',
#   'recipe_index': 'Misc_3',
#   'rating': nan,
#   'quantity': 1.333333333,
#   'unit': 'cup'},
#  {'entry_no': 444,
#   'ingredient': 'bread flour',
#   'text': '2.66666666667 cups bread flour',
#   'recipe_index': 'Misc_49',
#   'rating': nan,
#   'quantity': 2.666666667,
#   'unit': 'cup'},
#  {'entry_no': 445,
#   'ingredient': 'bread flour',
#   'text': '2.22222222222 cupsbread flour',
#   'recipe_index': 'Misc_94',
#   'rating': nan,
#   'quantity': 2.222222222,
#   'unit': 'cup'},
#  {'entry_no': 446,
#   'ingredient': 'brown rice flour',
#   'text': '1.33333333333 cups brown rice flour mix',
#   'recipe_index': 'E_197',
#   'rating': 0.875,
#   'quantity': 1.333333333,
#   'unit': 'cup'},
#  {'entry_no': 636,
#   'ingredient': 'butter',
#   'text': '1.0 cup butter softened',
#   'recipe_index': 'AR_1',
#   'rating': 0.920724583,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 637,
#   'ingredient': 'butter',
#   'text': '0.5333333333333333 cup butter softened',
#   'recipe_index': 'AR_10',
#   'rating': 0.905162048,
#   'quantity': 0.533333333,
#   'unit': 'cup'},
#  {'entry_no': 638,
#   'ingredient': 'butter',
#   'text': '0.6666666666666666 cup butter softened',
#   'recipe_index': 'AR_102',
#   'rating': 0.9375,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 639,
#   'ingredient': 'butter',
#   'text': '0.8 cup butter softened',
#   'recipe_index': 'AR_103',
#   'rating': 0.88125,
#   'quantity': 0.8,
#   'unit': 'cup'},
#  {'entry_no': 640,
#   'ingredient': 'butter',
#   'text': '1.3333333333333333 cup butter',
#   'recipe_index': 'AR_11',
#   'rating': 0.902891922,
#   'quantity': 1.333333333,
#   'unit': 'cup'},
#  {'entry_no': 641,
#   'ingredient': 'butter',
#   'text': '1.0 cup butter',
#   'recipe_index': 'AR_110',
#   'rating': 0.868292713,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 642,
#   'ingredient': 'butter',
#   'text': '1.0 cup butter softened',
#   'recipe_index': 'AR_111',
#   'rating': 1.0,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 643,
#   'ingredient': 'butter',
#   'text': '1.5 cups butter softened',
#   'recipe_index': 'AR_119',
#   'rating': 0.845714283,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  {'entry_no': 644,
#   'ingredient': 'butter',
#   'text': '1.0 cup butter softened',
#   'recipe_index': 'AR_12',
#   'rating': 0.873469353,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 645,
#   'ingredient': 'butter',
#   'text': '2.0 cup butter melted',
#   'recipe_index': 'AR_128',
#   'rating': 0.714285707,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 646,
#   'ingredient': 'butter',
#   'text': '0.6666666666666666 cup unsalted butter',
#   'recipe_index': 'AR_14',
#   'rating': 0.90666666,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 647,
#   'ingredient': 'butter',
#   'text': '1.3333333333333333 cup butter',
#   'recipe_index': 'AR_140',
#   'rating': 0.584615374,
#   'quantity': 1.333333333,
#   'unit': 'cup'},
#  {'entry_no': 648,
#   'ingredient': 'butter',
#   'text': '16.0 tablespoons butter',
#   'recipe_index': 'AR_142',
#   'rating': 0.671428585,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 649,
#   'ingredient': 'butter',
#   'text': '1.0 cup butter softened',
#   'recipe_index': 'AR_144',
# ...
#   'ingredient': 'salt',
#   'text': '2.66666666667 teaspoon salt i prefer coarse sea salt',
#   'recipe_index': 'Misc_99',
#   'rating': nan,
#   'quantity': 2.666666667,
#   'unit': 'teaspoon'},
#  {'entry_no': 1526,
#   'ingredient': 'shortening',
#   'text': '0.5333333333333333 cup butter flavored shortening',
#   'recipe_index': 'AR_10',
#   'rating': 0.905162048,
#   'quantity': 0.533333333,
#   'unit': 'cup'},
#  {'entry_no': 1527,
#   'ingredient': 'shortening',
#   'text': '2.0 cup shortening',
#   'recipe_index': 'AR_107',
#   'rating': 0.927272701,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1528,
#   'ingredient': 'shortening',
#   'text': '0.5714285714285714 cup shortening',
#   'recipe_index': 'AR_108',
#   'rating': 0.867741966,
#   'quantity': 0.571428571,
#   'unit': 'cup'},
#  {'entry_no': 1529,
#   'ingredient': 'shortening',
#   'text': '0.6666666666666666 cup shortening',
#   'recipe_index': 'AR_109',
#   'rating': 0.871794891,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1530,
#   'ingredient': 'shortening',
#   'text': '1.0 cup shortening',
#   'recipe_index': 'AR_111',
#   'rating': 1.0,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1531,
#   'ingredient': 'shortening',
#   'text': '0.5 cup shortening',
#   'recipe_index': 'AR_116',
#   'rating': 0.847999954,
#   'quantity': 0.5,
#   'unit': 'cup'},
#  {'entry_no': 1532,
#   'ingredient': 'shortening',
#   'text': '0.8 cup shortening',
#   'recipe_index': 'AR_118',
#   'rating': 0.830769253,
#   'quantity': 0.8,
#   'unit': 'cup'},
#  {'entry_no': 1533,
#   'ingredient': 'shortening',
#   'text': '2.0 cup shortening',
#   'recipe_index': 'AR_13',
#   'rating': 0.909016418,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1534,
#   'ingredient': 'shortening',
#   'text': '1.3333333333333333 cup shortening',
#   'recipe_index': 'AR_141',
#   'rating': 0.784615374,
#   'quantity': 1.333333333,
#   'unit': 'cup'},
#  {'entry_no': 1535,
#   'ingredient': 'shortening',
#   'text': '1.0 cup butter flavored shortening',
#   'recipe_index': 'AR_144',
#   'rating': 0.442857122,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1536,
#   'ingredient': 'shortening',
#   'text': '1.3333333333333333 cup shortening',
#   'recipe_index': 'AR_19',
#   'rating': 0.880000019,
#   'quantity': 1.333333333,
#   'unit': 'cup'},
#  {'entry_no': 1537,
#   'ingredient': 'shortening',
#   'text': '2.0 cups butter flavored shortening',
#   'recipe_index': 'AR_21',
#   'rating': 0.881944466,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1538,
#   'ingredient': 'shortening',
#   'text': '1.3333333333333333 cup shortening',
#   'recipe_index': 'AR_218',
#   'rating': 0.877419376,
#   'quantity': 1.333333333,
#   'unit': 'cup'},
#  {'entry_no': 1539,
#   'ingredient': 'shortening',
#   'text': '2.0 cups butter flavored shortening',
#   'recipe_index': 'AR_28',
#   'rating': 0.873333359,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1540,
#   'ingredient': 'shortening',
#   'text': '1.0 cups shortening',
#   'recipe_index': 'AR_32',
#   'rating': 0.830769253,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1541,
#   'ingredient': 'shortening',
#   'text': '4.0 cup butter flavored shortening',
#   'recipe_index': 'AR_47',
#   'rating': 0.7125,
#   'quantity': 4.0,
#   'unit': 'cup'},
#  {'entry_no': 1542,
#   'ingredient': 'shortening',
#   'text': '1.0 cup shortening',
#   'recipe_index': 'AR_50',
#   'rating': 0.66500001,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1543,
#   'ingredient': 'shortening',
#   'text': '2.0 cup butter flavored shortening',
#   'recipe_index': 'AR_66',
#   'rating': 0.902002907,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1544,
#   'ingredient': 'shortening',
#   'text': '0.8 cup butter flavored shortening',
#   'recipe_index': 'AR_89',
#   'rating': 0.909890079,
#   'quantity': 0.8,
#   'unit': 'cup'},
#  {'entry_no': 1545,
#   'ingredient': 'shortening',
#   'text': '1.0 cup shortening',
#   'recipe_index': 'AR_91',
#   'rating': 0.928301907,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1546,
#   'ingredient': 'shortening',
#   'text': '0.666666666667 cup vegetable shortening preferably trans fat free plus additional for greasing baking sheets',
#   'recipe_index': 'E_197',
#   'rating': 0.875,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1547,
#   'ingredient': 'shortening',
#   'text': '1.2 cup solid vegetable shortening',
#   'recipe_index': 'E_26',
#   'rating': 0.875,
#   'quantity': 1.2,
#   'unit': 'cup'},
#  {'entry_no': 1548,
#   'ingredient': 'shortening',
#   'text': '0.571428571429 cup solid vegetable shortening room temperature',
#   'recipe_index': 'E_375',
#   'rating': 0.75,
#   'quantity': 0.571428571,
#   'unit': 'cup'},
#  {'entry_no': 1549,
#   'ingredient': 'shortening',
#   'text': '0.666666666667 cup vegetable shortening',
#   'recipe_index': 'Misc_18',
#   'rating': nan,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1550,
#   'ingredient': 'shortening',
#   'text': '0.4 cup shortening',
#   'recipe_index': 'Misc_31',
#   'rating': nan,
#   'quantity': 0.4,
#   'unit': 'cup'},
#  {'entry_no': 1551,
#   'ingredient': 'shortening',
#   'text': '0.666666666667 cup shortening',
#   'recipe_index': 'Misc_46',
#   'rating': nan,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1552,
#   'ingredient': 'shortening',
#   'text': '0.666666666667 cup vegetable shortening',
#   'recipe_index': 'Misc_48',
#   'rating': nan,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1553,
#   'ingredient': 'shortening',
#   'text': '1.0 cup criscoÂ® butter flavor all vegetable shortening',
#   'recipe_index': 'Misc_54',
#   'rating': nan,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1554,
#   'ingredient': 'shortening',
#   'text': '0.666666666667 cup vegetable shortening',
#   'recipe_index': 'Misc_85',
#   'rating': nan,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1555,
#   'ingredient': 'sour cream',
#   'text': '1.0 cup sour cream',
#   'recipe_index': 'AR_48',
#   'rating': 0.677777767,
#   'quantity': 16.0,
#   'unit': 'tablespoon'},
#  {'entry_no': 1556,
#   'ingredient': 'sour cream',
#   'text': '2.4 tablespoon sour cream',
#   'recipe_index': 'E_26',
#   'rating': 0.875,
#   'quantity': 2.4,
#   'unit': 'tablespoon'},
#  {'entry_no': 1557,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_1',
#   'rating': 0.920724583,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1558,
#   'ingredient': 'sugar',
#   'text': '0.8 cup white sugar',
#   'recipe_index': 'AR_10',
#   'rating': 0.905162048,
#   'quantity': 0.8,
#   'unit': 'cup'},
#  {'entry_no': 1559,
#   'ingredient': 'sugar',
#   'text': '0.7384615384615385 cups white sugar',
#   'recipe_index': 'AR_101',
#   'rating': 0.6,
#   'quantity': 0.738461538,
#   'unit': 'cup'},
#  {'entry_no': 1560,
#   'ingredient': 'sugar',
#   'text': '0.3333333333333333 cup white sugar',
#   'recipe_index': 'AR_102',
#   'rating': 0.9375,
#   'quantity': 0.333333333,
#   'unit': 'cup'},
#  {'entry_no': 1561,
#   'ingredient': 'sugar',
#   'text': '0.4 cup white sugar',
#   'recipe_index': 'AR_103',
#   'rating': 0.88125,
#   'quantity': 0.4,
#   'unit': 'cup'},
#  {'entry_no': 1562,
#   'ingredient': 'sugar',
#   'text': '3.0 cup white sugar',
#   'recipe_index': 'AR_107',
#   'rating': 0.927272701,
#   'quantity': 3.0,
#   'unit': 'cup'},
#  {'entry_no': 1563,
#   'ingredient': 'sugar',
#   'text': '0.2857142857142857 cup white sugar',
#   'recipe_index': 'AR_108',
#   'rating': 0.867741966,
#   'quantity': 0.285714286,
#   'unit': 'cup'},
#  {'entry_no': 1564,
#   'ingredient': 'sugar',
#   'text': '0.6666666666666666 cup white sugar',
#   'recipe_index': 'AR_109',
#   'rating': 0.871794891,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1565,
#   'ingredient': 'sugar',
#   'text': '0.6666666666666666 cup white sugar',
#   'recipe_index': 'AR_11',
#   'rating': 0.902891922,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1566,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_110',
#   'rating': 0.868292713,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1567,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_111',
#   'rating': 1.0,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1568,
#   'ingredient': 'sugar',
#   'text': '0.5 cup white sugar',
#   'recipe_index': 'AR_116',
#   'rating': 0.847999954,
#   'quantity': 0.5,
#   'unit': 'cup'},
#  {'entry_no': 1569,
#   'ingredient': 'sugar',
#   'text': '0.8 cup white sugar',
#   'recipe_index': 'AR_118',
#   'rating': 0.830769253,
#   'quantity': 0.8,
#   'unit': 'cup'},
#  {'entry_no': 1570,
#   'ingredient': 'sugar',
#   'text': '1.25 cups white sugar',
#   'recipe_index': 'AR_119',
#   'rating': 0.845714283,
#   'quantity': 1.25,
#   'unit': 'cup'},
#  {'entry_no': 1571,
#   'ingredient': 'sugar',
#   'text': '0.5 cup granulated sugar',
#   'recipe_index': 'AR_12',
#   'rating': 0.873469353,
#   'quantity': 0.5,
#   'unit': 'cup'},
#  {'entry_no': 1572,
#   'ingredient': 'sugar',
#   'text': '1.5 cup white sugar',
#   'recipe_index': 'AR_128',
#   'rating': 0.714285707,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  {'entry_no': 1573,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_13',
#   'rating': 0.909016418,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1574,
#   'ingredient': 'sugar',
#   'text': '0.6666666666666666 cup white sugar',
#   'recipe_index': 'AR_14',
#   'rating': 0.90666666,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1575,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_140',
#   'rating': 0.584615374,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1576,
#   'ingredient': 'sugar',
#   'text': '1.5 cup white sugar',
#   'recipe_index': 'AR_142',
#   'rating': 0.671428585,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  {'entry_no': 1577,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_144',
#   'rating': 0.442857122,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1578,
#   'ingredient': 'sugar',
#   'text': '0.25 cup white sugar',
#   'recipe_index': 'AR_15',
#   'rating': 0.924302769,
#   'quantity': 0.25,
#   'unit': 'cup'},
#  {'entry_no': 1579,
#   'ingredient': 'sugar',
#   'text': '0.3333333333333333 cup white sugar',
#   'recipe_index': 'AR_155',
#   'rating': 0.931135178,
#   'quantity': 0.333333333,
#   'unit': 'cup'},
#  {'entry_no': 1580,
#   'ingredient': 'sugar',
#   'text': '2.0 cup white sugar',
#   'recipe_index': 'AR_156',
#   'rating': 0.924294472,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1581,
#   'ingredient': 'sugar',
#   'text': '1.1428571428571428 cups white sugar',
#   'recipe_index': 'AR_16',
#   'rating': 0.85882349,
#   'quantity': 1.142857143,
#   'unit': 'cup'},
#  {'entry_no': 1582,
#   'ingredient': 'sugar',
#   'text': '0.75 cup granulated sugar',
#   'recipe_index': 'AR_164',
#   'rating': 0.917012405,
#   'quantity': 0.75,
#   'unit': 'cup'},
#  {'entry_no': 1583,
#   'ingredient': 'sugar',
#   'text': '1.3333333333333333 cup white sugar',
#   'recipe_index': 'AR_19',
#   'rating': 0.880000019,
#   'quantity': 1.333333333,
#   'unit': 'cup'},
#  {'entry_no': 1584,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_196',
#   'rating': 0.785929632,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1585,
#   'ingredient': 'sugar',
#   'text': '2.0 cup white sugar',
#   'recipe_index': 'AR_197',
#   'rating': 0.706521749,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1586,
#   'ingredient': 'sugar',
#   'text': '0.6666666666666666 cup white sugar',
#   'recipe_index': 'AR_2',
#   'rating': 0.937981987,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1587,
#   'ingredient': 'sugar',
#   'text': '0.6666666666666666 cup white sugar',
#   'recipe_index': 'AR_218',
#   'rating': 0.877419376,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1588,
#   'ingredient': 'sugar',
#   'text': '12.0 tablespoons white sugar',
#   'recipe_index': 'AR_256',
#   'rating': 0.870253181,
#   'quantity': 0.73,
#   'unit': 'cup'},
#  {'entry_no': 1589,
#   'ingredient': 'sugar',
#   'text': '0.75 cup white sugar',
#   'recipe_index': 'AR_26',
#   'rating': 0.9,
#   'quantity': 0.75,
#   'unit': 'cup'},
#  {'entry_no': 1590,
#   'ingredient': 'sugar',
#   'text': '2.0 cups white sugar',
#   'recipe_index': 'AR_27',
#   'rating': 0.876923084,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1591,
#   'ingredient': 'sugar',
#   'text': '1.5 cups white sugar',
#   'recipe_index': 'AR_28',
#   'rating': 0.873333359,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  {'entry_no': 1592,
#   'ingredient': 'sugar',
#   'text': '0.5 cup white sugar',
#   'recipe_index': 'AR_280',
#   'rating': nan,
#   'quantity': 0.5,
#   'unit': 'cup'},
#  {'entry_no': 1593,
#   'ingredient': 'sugar',
#   'text': '0.25 cup white sugar',
#   'recipe_index': 'AR_3',
#   'rating': 0.917986774,
#   'quantity': 0.25,
#   'unit': 'cup'},
#  {'entry_no': 1594,
#   'ingredient': 'sugar',
#   'text': '0.5 cup white sugar',
#   'recipe_index': 'AR_30',
#   'rating': 0.859829044,
#   'quantity': 0.5,
#   'unit': 'cup'},
#  {'entry_no': 1595,
#   'ingredient': 'sugar',
#   'text': '0.8 cup white sugar',
#   'recipe_index': 'AR_32',
#   'rating': 0.830769253,
#   'quantity': 0.8,
#   'unit': 'cup'},
#  {'entry_no': 1596,
#   'ingredient': 'sugar',
#   'text': '0.6666666666666666 cup white sugar',
#   'recipe_index': 'AR_33',
#   'rating': 0.826666641,
#   'quantity': 0.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1597,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_35',
#   'rating': 0.843636322,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1598,
#   'ingredient': 'sugar',
#   'text': '1.6666666666666665 cups white sugar',
#   'recipe_index': 'AR_37',
#   'rating': 0.8,
#   'quantity': 1.666666667,
#   'unit': 'cup'},
#  {'entry_no': 1599,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_39',
#   'rating': 0.6,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1600,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_4',
#   'rating': 0.922985077,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1601,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_43',
#   'rating': 0.828866005,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1602,
#   'ingredient': 'sugar',
#   'text': '0.75 cup white sugar',
#   'recipe_index': 'AR_45',
#   'rating': 0.821052647,
#   'quantity': 0.75,
#   'unit': 'cup'},
#  {'entry_no': 1603,
#   'ingredient': 'sugar',
#   'text': '3.0 cup white sugar',
#   'recipe_index': 'AR_47',
#   'rating': 0.7125,
#   'quantity': 3.0,
#   'unit': 'cup'},
#  {'entry_no': 1604,
#   'ingredient': 'sugar',
#   'text': '1.5 cup white sugar',
#   'recipe_index': 'AR_48',
#   'rating': 0.677777767,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  {'entry_no': 1605,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_49',
#   'rating': 0.592592573,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1606,
#   'ingredient': 'sugar',
#   'text': '0.75 cup white sugar',
#   'recipe_index': 'AR_5',
#   'rating': 0.937341785,
#   'quantity': 0.75,
#   'unit': 'cup'},
#  {'entry_no': 1607,
#   'ingredient': 'sugar',
#   'text': '2.0 cups white sugar',
#   'recipe_index': 'AR_50',
#   'rating': 0.66500001,
#   'quantity': 2.0,
#   'unit': 'cup'},
#  {'entry_no': 1608,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_53',
#   'rating': 0.692473125,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1609,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_54',
#   'rating': 0.723741007,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1610,
#   'ingredient': 'sugar',
#   'text': '1.5 cup white sugar',
#   'recipe_index': 'AR_55',
#   'rating': 0.385714293,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  {'entry_no': 1611,
#   'ingredient': 'sugar',
#   'text': '1.0 cup white sugar',
#   'recipe_index': 'AR_57',
#   'rating': 0.595505619,
#   'quantity': 1.0,
#   'unit': 'cup'},
#  {'entry_no': 1612,
#   'ingredient': 'sugar',
#   'text': '1.5 cup white sugar',
#   'recipe_index': 'AR_66',
#   'rating': 0.902002907,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  {'entry_no': 1613,
#   'ingredient': 'sugar',
#   'text': '1.5 cup white sugar',
#   'recipe_index': 'AR_67',
#   'rating': 0.939130402,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  {'entry_no': 1614,
#   'ingredient': 'sugar',
#   'text': '1.5 cup white sugar',
#   'recipe_index': 'AR_69',
#   'rating': 0.920792103,
#   'quantity': 1.5,
#   'unit': 'cup'},
#  ...]

# %% [markdown]
# ## Creating a Pandas DataFrame for Ingredients

# %%
import pandas as pd

# %%
df_ingredients = pd.DataFrame(ingredient_dicts)
df_ingredients.head()
# Out:
#    entry_no         ingredient  \
# 0         1  all purpose flour
# 1         2  all purpose flour
# 2         3  all purpose flour
# 3         4  all purpose flour
# 4         5  all purpose flour
#
#                                               text recipe_index    rating  \
# 0                       3.0 cups all purpose flour         AR_1  0.920725
# 1        2.8000000000000003 cups all purpose flour        AR_10  0.905162
# 2        1.1076923076923078 cups all purpose flour       AR_101  0.600000
# 3  3.333333333333333 cups sifted all purpose flour       AR_102  0.937500
# 4                       2.0 cups all purpose flour       AR_103  0.881250
#
#    quantity unit
# 0  3.000000  cup
# 1  2.800000  cup
# 2  1.107692  cup
# 3  3.333333  cup
# 4  2.000000  cup

# %% [markdown]
# The researchers wanted to sort the ingredients by their rating and recipe index, so they did using the `sort_values` function.

# %%
df_ingredients = df_ingredients.sort_values(by = "recipe_index")
df_ingredients.head()
# Out:
#       entry_no                ingredient                                text  \
# 0            1         all purpose flour          3.0 cups all purpose flour
# 1783       821  semisweet chocolate chip  2.0 cups semisweet chocolate chips
# 250        251               baking soda            1.0 teaspoon baking soda
# 1576       447         light brown sugar          1.0 cup packed brown sugar
# 1565      1980                     water             2.0 teaspoons hot water
#
#      recipe_index    rating  quantity      unit
# 0            AR_1  0.920725     3.000       cup
# 1783         AR_1  0.920725     2.000       cup
# 250          AR_1  0.920725     1.000  teaspoon
# 1576         AR_1  0.920725     1.000       cup
# 1565         AR_1  0.920725     0.041       cup

# %% [markdown]
# # Writing File

# %%
recipe_indices = list(df_ingredients["recipe_index"].unique())

out_file_text = ""

for i_recipe in recipe_indices:
    new_recipe = "\n" + i_recipe
    recipe = df_ingredients[df_ingredients["recipe_index"] == i_recipe]

    for ingredient_name in recipe["text"].unique():
        new_recipe += "\n " + ingredient_name

    new_recipe += "\n " + str(recipe.iloc[0]["rating"])

    out_file_text += new_recipe

out_file = open("recipe.txt", mode = 'w', encoding="iso-8859-1")
out_file.write(out_file_text[1:])
out_file.close()
